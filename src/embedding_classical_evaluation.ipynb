# %% [markdown]
# # Evaluation of unbiased word embeddings on similarities and analogies benchmarks
#
# 1. [1] [GloVe](https://nlp.stanford.edu/projects/glove/) Global Vectors for Word Representation from stanford.
# 1. [2] [GN GloVe](https://arxiv.org/abs/1809.01496) Learning Gender-Neutral Word Embeddings trained on wikipedia. The embeddings contain a gender neutral
# 1. [3] [Word2vec](https://code.google.com/archive/p/word2vec/)
# 1. [4] [Debiaswe](https://github.com/tolga-b/debiaswe) Unbiased Word2Vec
#
# ## Benchmarks
# We will evaluate the embeddings using some of the datasets listed in this paper: [A Survey of Word Embeddings Evaluation Methods](https://arxiv.org/abs/1801.09536)
#
# ### Word similarities
# 1. [SimVerb-3500](https://arxiv.org/abs/1608.00869): 3 500 pairs of verbs assessed by semantic similarity with a scale from 0 to 4
# 1. [SimLex-999](https://fh295.github.io/simlex.html): 999 pairs assessed with a strong respect to semantic similarity
# with a scale from 0 to 10
# 1. [MEN](https://staff.fnwi.uva.nl/e.bruni/MEN): 3 000 pairs assessed by semantic relatedness with a discrete scale from 0 to 50
#
# ### Word analogies
# 1. [Google Analogy](https://arxiv.org/abs/1301.3781): Contains 19,544 question pairs (8,869 semantic and 10,675 syntactic questions)
# 1. [MSR](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/rvecs.pdf) (Microsoft Research Syntactic Analogies): 8,000 questions divided into 16 morphological classes
#
# ## Reproducibility
# During our research, some embeddings / datasets were no longer available at their original URL. So to ensure the reproducibility of our experiments, we stored a copy of the datasets on [Renku](https://renkulab.io/projects/samuel.betrisey/embedding-classical-evaluation/datasets)

# %%
# !pip install gensim==4.1.2 gdown
# Out:
# Requirement already satisfied: gensim==4.1.2 in /usr/local/lib/python3.7/dist-packages (4.1.2)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.4.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.21.6)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (6.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.7.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gensim.downloader
from gensim.models import KeyedVectors
from pandas import read_csv, DataFrame
import requests
from six import BytesIO
from zipfile import ZipFile
from pathlib import Path
import gdown
import os

data_dir = Path("data")
data_dir.mkdir(exist_ok=True)

# %%
paths = {
    "GloVe_Stanford" : "glove.6B.300d.txt",
    "Unbiased_GloVe" : "1b-vectors300-0.8-0.8.txt",
    "Unbiased_Word2Vec" : "GoogleNews-vectors-negative300-hard-debiased.bin.gz", 
    'Word2Vec' : None # Downloaded directly from gensim
}

if not (data_dir / paths['GloVe_Stanford']).exists():
    #zip_file = gdown.download("http://nlp.stanford.edu/data/glove.6B.zip")
    #ZipFile(zip_file).extract(paths['GloVe_Stanford'], "data")
    #os.remove(zip_file)
    gdown.download("https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/embeddings/glove.6B.300d.txt",
                   output=str(data_dir / paths["GloVe_Stanford"]))
glove_vectors = KeyedVectors.load_word2vec_format(data_dir / paths['GloVe_Stanford'], binary=False, no_header=True)

# gender neutral glove from https://github.com/uclanlp/gn_glove
if not (data_dir / paths['Unbiased_GloVe']).exists():
    #zip_file = gdown.download("https://drive.google.com/uc?id=1g1QPqbIlQorwlfGShtPbZVk6mfwodQgE")
    #ZipFile(zip_file).extract(paths['Unbiased_GloVe'], "data")
    #os.remove(zip_file)
    gdown.download("https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/embeddings/1b-vectors300-0.8-0.8.txt",
                   output=str(data_dir / paths["Unbiased_GloVe"]))
unbiased_glove_vectors = KeyedVectors.load_word2vec_format(data_dir / paths['Unbiased_GloVe'], binary=False, no_header=True)

gensim.downloader.DOWNLOAD_BASE_URL = "https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/embeddings"
word2vec_vectors = gensim.downloader.load("word2vec-google-news-300")

# https://github.com/tolga-b/debiaswe
if not (data_dir / paths['Unbiased_Word2Vec']).exists():
    #gdown.download("https://drive.google.com/uc?id=0B5vZVlu2WoS5ZTBSekpUX0RSNDg", output=str(data_dir / paths["Unbiased_Word2Vec"]))
    gdown.download("https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/embeddings/GoogleNews-vectors-negative300-hard-debiased.bin.gz",
                   output=str(data_dir / paths["Unbiased_Word2Vec"]))
unbiased_word2vec_vectors = KeyedVectors.load_word2vec_format(data_dir / paths['Unbiased_Word2Vec'], binary=True)

# %%
MODELS = {"GloVe_Stanford": glove_vectors,
          "Unbiased_GloVe": unbiased_glove_vectors,
          "Word2Vec": word2vec_vectors,
          "Unbiased_Word2Vec": unbiased_word2vec_vectors}

# %%
# https://arxiv.org/pdf/1608.00869.pdf
#url = "https://www.repository.cam.ac.uk/bitstream/handle/1810/264124/simverb-3500-data.zip"
url = "https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/evaluation/simverb-3500-data.zip"
simverb = read_csv(ZipFile(BytesIO(requests.get(url).content)).open("data/SimVerb-3500.txt"), sep="\t", header=None)
simverb_path = "data/SimVerb-3500.txt"
simverb = simverb[[0, 1, 3]]
simverb.to_csv(simverb_path, sep="\t", header=False, index=False)
simverb
# Out:
#                 0         1     3
# 0            take    remove  6.81
# 1            walk     trail  4.81
# 2            feed    starve  1.49
# 3           shine    polish  7.80
# 4       calculate       add  5.98
# ...           ...       ...   ...
# 3495       impose     cheat  1.16
# 3496        rebel   protest  7.64
# 3497  collaborate  conspire  4.23
# 3498     conspire   protest  1.83
# 3499      protest   release  1.16
#
# [3500 rows x 3 columns]

# %%
# https://fh295.github.io/simlex.html
#url = "https://fh295.github.io/SimLex-999.zip"
url = "https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/evaluation/SimLex-999.zip"
simlex = read_csv(ZipFile(BytesIO(requests.get(url).content)).open("SimLex-999/SimLex-999.txt"), sep="\t")
simlex = simlex[["word1", "word2", "SimLex999"]]
simlex_path = "data/SimLex-999.txt"
simlex.to_csv(simlex_path, sep="\t", header=False, index=False)
simlex
# Out:
#       word1        word2  SimLex999
# 0       old          new       1.58
# 1     smart  intelligent       9.20
# 2      hard    difficult       8.77
# 3     happy     cheerful       9.55
# 4      hard         easy       0.95
# ..      ...          ...        ...
# 994    join      acquire       2.85
# 995    send       attend       1.67
# 996  gather       attend       4.80
# 997  absorb     withdraw       2.97
# 998  attend       arrive       6.08
#
# [999 rows x 3 columns]

# %%
# https://staff.fnwi.uva.nl/e.bruni/MEN
#url = "https://staff.fnwi.uva.nl/e.bruni/resources/MEN.zip"
url = "https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/evaluation/MEN.zip"
men = read_csv(ZipFile(BytesIO(requests.get(url).content)).open("MEN/MEN_dataset_natural_form_full"), sep=" ")
men_path = "data/MEN.txt"
men.to_csv(men_path, sep="\t", header=False, index=False)
men
# Out:
#              sun   sunlight  50.000000
# 0     automobile        car       50.0
# 1          river      water       49.0
# 2         stairs  staircase       49.0
# 3        morning    sunrise       49.0
# 4           rain      storm       49.0
# ...          ...        ...        ...
# 2994    feathers      truck        1.0
# 2995    festival   whiskers        1.0
# 2996      muscle      tulip        1.0
# 2997      bikini      pizza        1.0
# 2998      bakery      zebra        0.0
#
# [2999 rows x 3 columns]

# %%
TESTS = {"simverb": simverb_path,
         "simlex": simlex_path,
         "men": men_path}

for model_name, model in MODELS.items():
    print(f"Model: {model_name}")
    for test_name, test in TESTS.items():
        print(f"  Test: {test_name}")
        print("    " + str(model.evaluate_word_pairs(test)))

# Output format: ((Pearson r, Pearson p), (Spearman r, Spearman p))
# Out:
# Model: GloVe_Stanford
#   Test: simverb
#     ((0.23014955028065393, 2.822815350386805e-43), SpearmanrResult(correlation=0.226666174150116, pvalue=5.3917592196100066e-42), 0.05714285714285715)
#   Test: simlex
#     ((0.3877827890006341, 3.687650450670567e-37), SpearmanrResult(correlation=0.3692121013345344, pvalue=1.371018956747063e-33), 0.10010010010010009)
#   Test: men
#     ((0.7431576592641206, 0.0), SpearmanrResult(correlation=0.7484863201719878, pvalue=0.0), 0.0)
# Model: Unbiased_GloVe
#   Test: simverb
#     ((0.21966858392073654, 2.2873693364746173e-39), SpearmanrResult(correlation=0.21820033173276157, pvalue=7.468453915772925e-39), 0.37142857142857144)
#   Test: simlex
#     ((0.34692400883694824, 1.3308688685445175e-29), SpearmanrResult(correlation=0.33936603261749826, pvalue=2.541683378519855e-28), 0.10010010010010009)
#   Test: men
#     ((0.5967259999587126, 8.321626556920017e-289), SpearmanrResult(correlation=0.5944851269439396, pvalue=4.1124826205567506e-286), 0.0)
# Model: Unbiased_Word2Vec
#   Test: simverb
#     ((0.35954596963639684, 3.779117014897495e-107), SpearmanrResult(correlation=0.3494916905115155, pvalue=5.947908951876174e-101), 0.14285714285714285)
#   Test: simlex
#     ((0.44977414612133637, 7.328189938047275e-51), SpearmanrResult(correlation=0.4381632102262553, pvalue=4.503918950733594e-48), 0.10010010010010009)
#   Test: men
#     ((0.6796642947504126, 0.0), SpearmanrResult(correlation=0.6970197310232861, pvalue=0.0), 0.0)
# Model: Word2Vec
#   Test: simverb
#     ((0.35917048906085564, 6.499589595836945e-107), SpearmanrResult(correlation=0.3493437763017114, pvalue=7.308950896551368e-101), 0.14285714285714285)
#   Test: simlex
#     ((0.4471705573561379, 3.160267671963873e-50), SpearmanrResult(correlation=0.43607859778335434, pvalue=1.389641635335226e-47), 0.10010010010010009)
#   Test: men
#     ((0.6821343739524194, 0.0), SpearmanrResult(correlation=0.6994431820566173, pvalue=0.0), 0.0)

# %%
# url = "http://download.tensorflow.org/data/questions-words.txt"
url = "https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/evaluation/questions-words.txt"
google_analogies_path = gdown.download(url, output="data/google_analogies.txt")
# Out:
# Downloading...
# From: https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/evaluation/questions-words.txt
# To: /content/data/google_analogies.txt
# 100%|██████████| 604k/604k [00:00<00:00, 10.4MB/s]

# %%
#url = "https://github.com/vecto-ai/word-benchmarks/raw/master/word-analogy/monolingual/en/msr.csv"
url = "https://renkulab.io/gitlab/samuel.betrisey/embedding-classical-evaluation/-/raw/master/data/evaluation/msr.csv"
msr = read_csv("https://github.com/vecto-ai/word-benchmarks/raw/master/word-analogy/monolingual/en/msr.csv", sep=",")
msr_path = "data/msr.txt"
msr = msr[["word1", "word2", "word3", "target"]]
msr.to_csv(msr_path, sep=" ", header=[':', '', '', ''], index=False)
msr
# Out:
#        word1   word2     word3    target
# 0       good  better     rough   rougher
# 1     better    good   rougher     rough
# 2       good    best     rough  roughest
# 3       best    good  roughest     rough
# 4       best  better  roughest   rougher
# ...      ...     ...       ...       ...
# 7995    sent    send   avoided     avoid
# 7996    send   sends     avoid    avoids
# 7997   sends    send    avoids     avoid
# 7998   sends    sent    avoids   avoided
# 7999    sent   sends   avoided    avoids
#
# [8000 rows x 4 columns]

# %%
TESTS = {"msr": msr_path, "google_analogies": google_analogies_path}

scores_by_model_test = {}
details_by_model_test = {}

for model_name, model in MODELS.items():
    print(f"Model: {model_name}")
    scores_by_model_test[model_name] = {}
    details_by_model_test[model_name] = {}
    for test_name, test in TESTS.items():
        print(f"  Test: {test_name}")
        score, details = model.evaluate_word_analogies(test)
        scores_by_model_test[model_name][test_name] = score
        details_by_model_test[model_name][test_name] = details
        print("    " + str(score))
# Out:
# Model: GloVe_Stanford
#   Test: msr
#     0.6427142857142857
#   Test: google_analogies
#     0.7195422354510931
# Model: Unbiased_GloVe
#   Test: msr
#     0.5343731946851531
#   Test: google_analogies
#     0.618961577297125
# Model: Word2Vec
#   Test: msr
#     0.7362857142857143
#   Test: google_analogies
#     0.7401448525607863
# Model: Unbiased_Word2Vec
#   Test: msr
#     0.7365714285714285
#   Test: google_analogies
#     0.7373512674599069

# %% [markdown]
# ## Let's explore the results

# %%
def get_correct_incorrect(details):
    correct = set()
    incorrect = set()
    for section in details:
        for sample in section['correct']:
            correct.add(sample)
        for sample in section['incorrect']:
            incorrect.add(sample)
    return correct, incorrect

original_unbiased_pairs = [("GloVe_Stanford", "Unbiased_GloVe"), ("Word2Vec", "Unbiased_Word2Vec")]
for original, unbiased in original_unbiased_pairs:
    print(f"{original} -> {unbiased}")
    for test_name, test in TESTS.items():
        print(test_name)
        print(f"Accuracy: {scores_by_model_test[original][test_name]} -> {scores_by_model_test[unbiased][test_name]}")
        details_original = details_by_model_test[original][test_name]
        details_unbiased = details_by_model_test[unbiased][test_name]
        correct_original, incorrect_original = get_correct_incorrect(details_original)
        correct_unbiased, incorrect_unbiased = get_correct_incorrect(details_unbiased)
        # show results that were correct with original and are now wrong and the opposite
        print("correct -> incorrect")
        print(correct_original.intersection(incorrect_unbiased))
        print("incorrect -> correct")
        print(incorrect_original.intersection(correct_unbiased))
        [details_original]
        print()
    print()
# Out:
# GloVe_Stanford -> Unbiased_GloVe
# msr
# Accuracy: 0.6427142857142857 -> 0.5343731946851531
# correct -> incorrect
# {('PRETTIER', 'PRETTY', 'SHORTER', 'SHORT'), ('LARGEST', 'LARGE', 'WEAKEST', 'WEAK'), ('SLOW', 'SLOWER', 'NICE', 'NICER'), ('CHANGES', 'CHANGE', 'SAVES', 'SAVE'), ('TASTY', 'TASTIER', 'STICKY', 'STICKIER'), ('RAISE', 'RAISED', 'UNDERSTAND', 'UNDERSTOOD'), ('FUNNIER', 'FUNNIEST', 'LARGER', 'LARGEST'), ('SELL', 'SELLS', 'LIKE', 'LIKES'), ('NARROWEST', 'NARROWER', 'STEADIEST', 'STEADIER'), ('MILD', 'MILDEST', 'RISKY', 'RISKIEST'), ('STICKY', 'STICKIER', 'WISE', 'WISER'), ('SYSTEM', 'SYSTEMS', 'CITIZEN', 'CITIZENS'), ('SLIMMER', 'SLIMMEST', 'MILDER', 'MILDEST'), ('SLIMMER', 'SLIMMEST', 'WISER', 'WISEST'), ('FAIREST', 'FAIRER', 'MILDEST', 'MILDER'), ('GENTLE', 'GENTLEST', 'CLOSE', 'CLOSEST'), ('SMALLEST', 'SMALLER', 'NICEST', 'NICER'), ('PREVENTS', 'PREVENT', 'CONSIDERS', 'CONSIDER'), ('SMALLER', 'SMALLEST', 'BROADER', 'BROADEST'), ('MILDEST', 'MILDER', 'EASIEST', 'EASIER'), ('CLEARER', 'CLEAR', 'CLOSER', 'CLOSE'), ('MAN', 'MEN', 'REPORT', 'REPORTS'), ('MOVE', 'MOVES', 'ASK', 'ASKS'), ('TOUGHEST', 'TOUGHER', 'OLDEST', 'OLDER'), ('FAIR', 'FAIRER', 'NARROW', 'NARROWER'), ('BOLDER', 'BOLDEST', 'NARROWER', 'NARROWEST'), ('BELIEVES', 'BELIEVE', 'SEEKS', 'SEEK'), ('TAKES', 'TOOK', 'REDUCES', 'REDUCED'), ('SEEMED', 'SEEMS', 'AVOIDED', 'AVOIDS'), ('RICHER', 'RICHEST', 'TOUGHER', 'TOUGHEST'), ('ALLEGATIONS', 'ALLEGATION', 'POINTS', 'POINT'), ('BECOMES', 'BECOME', 'CELEBRATES', 'CELEBRATE'), ('BRING', 'BRINGS', 'RETURN', 'RETURNS'), ('LEAN', 'LEANEST', 'RISKY', 'RISKIEST'), ('CLEANER', 'CLEANEST', 'RICHER', 'RICHEST'), ('BROAD', 'BROADER', 'FAIR', 'FAIRER'), ('SMOOTHEST', 'SMOOTHER', 'MEANEST', 'MEANER'), ('GENTLEST', 'GENTLER', 'CLOSEST', 'CLOSER'), ('PROMOTE', 'PROMOTED', 'PRESERVE', 'PRESERVED'), ('PRETTY', 'PRETTIEST', 'FRIENDLY', 'FRIENDLIEST'), ('FRIENDLIEST', 'FRIENDLIER', 'COSTLIEST', 'COSTLIER'), ('FREER', 'FREEST', 'RICHER', 'RICHEST'), ('NARROWER', 'NARROWEST', 'SADDER', 'SADDEST'), ('STEADY', 'STEADIER', 'LUCKY', 'LUCKIER'), ('BELIEVES', 'BELIEVE', 'LIKES', 'LIKE'), ('NUMBER', 'NUMBERS', 'PRODUCT', 'PRODUCTS'), ('NICER', 'NICEST', 'FAIRER', 'FAIREST'), ('BEGINS', 'BEGIN', 'PROTECTS', 'PROTECT'), ('LIKE', 'LIKES', 'STUDY', 'STUDIES'), ('CLEANEST', 'CLEANER', 'FRIENDLIEST', 'FRIENDLIER'), ('FANCIEST', 'FANCIER', 'OLDEST', 'OLDER'), ('TRICKY', 'TRICKIEST', 'ROUGH', 'ROUGHEST'), ('DARK', 'DARKER', 'TASTY', 'TASTIER'), ('NARROWEST', 'NARROWER', 'SADDEST', 'SADDER'), ('WIDEST', 'WIDER', 'FRESHEST', 'FRESHER'), ('WORKED', 'WORKS', 'LIKED', 'LIKES'), ('FOLLOW', 'FOLLOWS', 'NEED', 'NEEDS'), ('INCLUDE', 'INCLUDES', 'STUDY', 'STUDIES'), ('FEWEST', 'FEW', 'STRONGEST', 'STRONG'), ('CLASSIER', 'CLASSIEST', 'FATTER', 'FATTEST'), ('MEAN', 'MEANER', 'CLASSY', 'CLASSIER'), ('CONSIDERS', 'CONSIDER', 'STUDIES', 'STUDY'), ('RISKIER', 'RISKIEST', 'SADDER', 'SADDEST'), ('FULLEST', 'FULL', 'NARROWEST', 'NARROW'), ('PRESERVE', 'PRESERVES', 'CHANGE', 'CHANGES'), ('NICEST', 'NICER', 'NOISIEST', 'NOISIER'), ('ACCOMMODATES', 'ACCOMMODATE', 'NEEDS', 'NEED'), ('COOLER', 'COOL', 'LIGHTER', 'LIGHT'), ('WEAKER', 'WEAKEST', 'SOFTER', 'SOFTEST'), ('LEANER', 'LEANEST', 'NEWER', 'NEWEST'), ('EASIEST', 'EASIER', 'LEANEST', 'LEANER'), ('ROUGHER', 'ROUGHEST', 'STEADIER', 'STEADIEST'), ('BENEFITS', 'BENEFIT', 'LAWS', 'LAW'), ('NARROW', 'NARROWER', 'SAD', 'SADDER'), ('FASTER', 'FAST', 'NICER', 'NICEST'), ('COMPANY', 'COMPANIES', 'VOTER', 'VOTERS'), ('WEALTHIEST', 'WEALTHIER', 'BLOODIEST', 'BLOODIER'), ('DISCUSSES', 'DISCUSSED', 'ACCOMMODATES', 'ACCOMMODATED'), ('SMARTEST', 'SMARTER', 'NARROWEST', 'NARROWER'), ('RECOGNIZED', 'RECOGNIZE', 'LEARNED', 'LEARN'), ('BLOODIER', 'BLOODIEST', 'FASTER', 'FAST'), ('MESSIER', 'MESSY', 'WORSE', 'BAD'), ('POINT', 'POINTS', 'CITIZEN', 'CITIZENS'), ('CLEARER', 'CLEAR', 'WEAKER', 'WEAK'), ('INCLUDE', 'INCLUDES', 'REMAIN', 'REMAINS'), ('ENDS', 'END', 'LEADS', 'LEAD'), ('COSTLY', 'COSTLIEST', 'TALL', 'TALLEST'), ('LOOK', 'LOOKED', 'DETERMINE', 'DETERMINED'), ('NOISIEST', 'NOISY', 'FANCIEST', 'FANCY'), ('THICKEST', 'THICK', 'FANCIEST', 'FANCY ...
# incorrect -> correct
# {('WEAPON', 'WEAPONS', 'DEATH', 'DEATHS'), ('BELIEVED', 'BELIEVES', 'BECAME', 'BECOMES'), ('HEALTHIEST', 'HEALTHY', 'SMALLEST', 'SMALL'), ('NICEST', 'NICE', 'HIGHEST', 'HIGH'), ('RETURN', 'RETURNED', 'INCLUDE', 'INCLUDED'), ('GREATEST', 'GREATER', 'FULLEST', 'FULLER'), ('ASK', 'ASKED', 'LOOK', 'LOOKED'), ('PARENT', 'PARENTS', 'CAR', 'CARS'), ('PRESERVED', 'PRESERVES', 'GAVE', 'GIVES'), ('WANT', 'WANTED', 'CHANGE', 'CHANGED'), ('LIKES', 'LIKED', 'FINDS', 'FOUND'), ('CHARGE', 'CHARGES', 'ANALYST', 'ANALYSTS'), ('DECIDES', 'DECIDED', 'BECOMES', 'BECAME'), ('BROADER', 'BROADEST', 'HIGHER', 'HIGHEST'), ('SUPPORTED', 'SUPPORTS', 'EARNED', 'EARNS'), ('FRIENDS', 'FRIEND', 'CHARGES', 'CHARGE'), ('BEGAN', 'BEGIN', 'LIVED', 'LIVE'), ('INCLUDE', 'INCLUDES', 'EARN', 'EARNS'), ('KNOWS', 'KNEW', 'STARTS', 'STARTED'), ('BUILDS', 'BUILT', 'FOLLOWS', 'FOLLOWED'), ('SMARTEST', 'SMART', 'SMALLEST', 'SMALL'), ('SAVES', 'SAVED', 'FOLLOWS', 'FOLLOWED'), ('FINDS', 'FOUND', 'NEEDS', 'NEEDED'), ('UNDERSTOOD', 'UNDERSTANDS', 'TRIED', 'TRIES'), ('LONGER', 'LONG', 'SMARTER', 'SMART'), ('MAKES', 'MAKE', 'OPENS', 'OPEN'), ('TAKES', 'TOOK', 'THINKS', 'THOUGHT'), ('INCLUDED', 'INCLUDES', 'REMAINED', 'REMAINS'), ('FRIENDLIER', 'FRIENDLY', 'COSTLIER', 'COSTLY'), ('IMPROVE', 'IMPROVED', 'LIVE', 'LIVED'), ('LEAVES', 'LEFT', 'HAPPENS', 'HAPPENED'), ('TELLS', 'TELL', 'SAYS', 'SAY'), ('STICKIER', 'STICKIEST', 'DARKER', 'DARKEST'), ('BRING', 'BROUGHT', 'WORK', 'WORKED'), ('HEALTHY', 'HEALTHIER', 'FULL', 'FULLER'), ('USES', 'USED', 'RAISES', 'RAISED'), ('TIMES', 'TIME', 'CITIZENS', 'CITIZEN'), ('ALLOWED', 'ALLOW', 'PRESERVED', 'PRESERVE'), ('KEPT', 'KEEP', 'HAD', 'HAVE'), ('LEAD', 'LEADS', 'PREVENT', 'PREVENTS'), ('PROVED', 'PROVES', 'TOLD', 'TELLS'), ('FANCY', 'FANCIER', 'OLD', 'OLDER'), ('SEEMED', 'SEEM', 'RESOLVED', 'RESOLVE'), ('INCREASE', 'INCREASED', 'INCLUDE', 'INCLUDED'), ('TOUGH', 'TOUGHEST', 'OLD', 'OLDEST'), ('SYSTEM', 'SYSTEMS', 'WORKER', 'WORKERS'), ('ALLOWED', 'ALLOWS', 'SOUGHT', 'SEEKS'), ('BIGGEST', 'BIGGER', 'GREATEST', 'GREATER'), ('SHOW', 'SHOWS', 'ALLOW', 'ALLOWS'), ('ASKED', 'ASK', 'REDUCED', 'REDUCE'), ('BOLD', 'BOLDEST', 'NEW', 'NEWEST'), ('LIVED', 'LIVE', 'CALLED', 'CALL'), ('PRODUCED', 'PRODUCE', 'LED', 'LEAD'), ('FEW', 'FEWER', 'CLEAR', 'CLEARER'), ('CELEBRATE', 'CELEBRATED', 'MAKE', 'MADE'), ('SUPPORTED', 'SUPPORT', 'EARNED', 'EARN'), ('RIGHT', 'RIGHTS', 'OFFICER', 'OFFICERS'), ('BOUGHT', 'BUYS', 'REMAINED', 'REMAINS'), ('BOLDER', 'BOLD', 'COOLER', 'COOL'), ('FRIEND', 'FRIENDS', 'MILE', 'MILES'), ('FOLLOW', 'FOLLOWED', 'LOOK', 'LOOKED'), ('TURNED', 'TURN', 'TRIED', 'TRY'), ('EXTENDS', 'EXTENDED', 'UNDERSTANDS', 'UNDERSTOOD'), ('STEEPEST', 'STEEPER', 'THICKEST', 'THICKER'), ('PRODUCT', 'PRODUCTS', 'CHARGE', 'CHARGES'), ('HAD', 'HAS', 'HELPED', 'HELPS'), ('SEES', 'SAW', 'SAYS', 'SAID'), ('FINDS', 'FOUND', 'MEETS', 'MET'), ('SUPPORT', 'SUPPORTED', 'EARN', 'EARNED'), ('CHANGES', 'CHANGE', 'TELLS', 'TELL'), ('STOPPED', 'STOPS', 'RAN', 'RUNS'), ('MOVED', 'MOVE', 'PRESERVED', 'PRESERVE'), ('BUILDS', 'BUILT', 'KNOWS', 'KNEW'), ('IMPROVES', 'IMPROVE', 'DOES', 'DO'), ('TRICKIEST', 'TRICKY', 'ROUGHEST', 'ROUGH'), ('REQUIRED', 'REQUIRES', 'MADE', 'MAKES'), ('MONTHS', 'MONTH', 'EXPERTS', 'EXPERT'), ('COOLER', 'COOLEST', 'PRETTIER', 'PRETTIEST'), ('OWNER', 'OWNERS', 'STATE', 'STATES'), ('TOUGHEST', 'TOUGH', 'SMARTEST', 'SMART'), ('DID', 'DO', 'LOOKED', 'LOOK'), ('SMART', 'SMARTEST', 'GREEN', 'GREENEST'), ('UNDERSTOOD', 'UNDERSTAND', 'TRIED', 'TRY'), ('PROMOTE', 'PROMOTED', 'DECIDE', 'DECIDED'), ('GREENEST', 'GREEN', 'EASIEST', 'EASY'), ('MEETS', 'MET', 'BUILDS', 'BUILT'), ('PRODUCES', 'PRODUCED', 'LEADS', 'LED'), ('MEMBERS', 'MEMBER', 'CHARGES', 'CHARGE'), ('OPEN', 'OPENS', 'LEAVE', 'LEAVES'), ('CLEAR', 'CLEAREST', 'WISE', 'WISEST'), ('SUPPORTS', 'SUPPORT', 'SEES', 'SEE'), ('HARDEST', 'HARD', 'BUSIEST', 'BUSY'), ('EXTENDED', 'EXTENDS', 'LIVED', 'LIVES'), ('SPORT', 'SPORTS', 'SCHOOL', 'SCHOOLS'), ('NARROW', 'NARROWER', 'STEADY', 'STEADIER'), ('DAY', 'DAYS' ...
#
# google_analogies
# Accuracy: 0.7195422354510931 -> 0.618961577297125
# correct -> incorrect
# {('ATHENS', 'GREECE', 'CHISINAU', 'MOLDOVA'), ('GREAT', 'GREATEST', 'EASY', 'EASIEST'), ('READING', 'READ', 'INCREASING', 'INCREASED'), ('EAGLE', 'EAGLES', 'WOMAN', 'WOMEN'), ('AUSTRALIA', 'AUSTRALIAN', 'ALBANIA', 'ALBANIAN'), ('GENERATE', 'GENERATING', 'MOVE', 'MOVING'), ('LOGICAL', 'ILLOGICAL', 'AWARE', 'UNAWARE'), ('VANISHING', 'VANISHED', 'WALKING', 'WALKED'), ('ACCRA', 'GHANA', 'APIA', 'SAMOA'), ('STEPBROTHER', 'STEPSISTER', 'STEPFATHER', 'STEPMOTHER'), ('SIMPLE', 'SIMPLEST', 'TALL', 'TALLEST'), ('UNFORTUNATE', 'UNFORTUNATELY', 'RARE', 'RARELY'), ('DARK', 'DARKEST', 'SLOW', 'SLOWEST'), ('SEARCH', 'SEARCHES', 'FIND', 'FINDS'), ('SUDDEN', 'SUDDENLY', 'QUICK', 'QUICKLY'), ('BRATISLAVA', 'SLOVAKIA', 'LILONGWE', 'MALAWI'), ('APIA', 'SAMOA', 'DOHA', 'QATAR'), ('USA', 'DOLLAR', 'ARGENTINA', 'PESO'), ('TALL', 'TALLEST', 'YOUNG', 'YOUNGEST'), ('PODGORICA', 'MONTENEGRO', 'WINDHOEK', 'NAMIBIA'), ('CANBERRA', 'AUSTRALIA', 'DUSHANBE', 'TAJIKISTAN'), ('EGYPT', 'EGYPTIAN', 'MACEDONIA', 'MACEDONIAN'), ('EASY', 'EASIEST', 'LONG', 'LONGEST'), ('LION', 'LIONS', 'WOMAN', 'WOMEN'), ('CROATIA', 'CROATIAN', 'ENGLAND', 'ENGLISH'), ('SWIM', 'SWIMMING', 'DISCOVER', 'DISCOVERING'), ('KOREA', 'KOREAN', 'MALTA', 'MALTESE'), ('PROFESSIONAL', 'PROFESSIONALLY', 'FREE', 'FREELY'), ('HUSBAND', 'WIFE', 'STEPBROTHER', 'STEPSISTER'), ('OSLO', 'NORWAY', 'THIMPHU', 'BHUTAN'), ('SIT', 'SITS', 'WRITE', 'WRITES'), ('RUSSIA', 'RUSSIAN', 'MOLDOVA', 'MOLDOVAN'), ('SWEET', 'SWEETEST', 'TALL', 'TALLEST'), ('SOFIA', 'BULGARIA', 'THIMPHU', 'BHUTAN'), ('WARM', 'WARMEST', 'SWEET', 'SWEETEST'), ('FEEDING', 'FED', 'RUNNING', 'RAN'), ('ENGLAND', 'ENGLISH', 'MACEDONIA', 'MACEDONIAN'), ('LUANDA', 'ANGOLA', 'OTTAWA', 'CANADA'), ('TAIPEI', 'TAIWAN', 'VADUZ', 'LIECHTENSTEIN'), ('ASTANA', 'KAZAKHSTAN', 'BAMAKO', 'MALI'), ('KAMPALA', 'UGANDA', 'MADRID', 'SPAIN'), ('BOTTLE', 'BOTTLES', 'MAN', 'MEN'), ('HONEST', 'DISHONEST', 'AWARE', 'UNAWARE'), ('ISRAEL', 'ISRAELI', 'MACEDONIA', 'MACEDONIAN'), ('NIAMEY', 'NIGER', 'OSLO', 'NORWAY'), ('BIG', 'BIGGEST', 'WARM', 'WARMEST'), ('DUSHANBE', 'TAJIKISTAN', 'NICOSIA', 'CYPRUS'), ('BEIJING', 'CHINA', 'GABORONE', 'BOTSWANA'), ('TIRANA', 'ALBANIA', 'ANTANANARIVO', 'MADAGASCAR'), ('WORK', 'WORKS', 'DECREASE', 'DECREASES'), ('PODGORICA', 'MONTENEGRO', 'ASMARA', 'ERITREA'), ('STEPBROTHER', 'STEPSISTER', 'KING', 'QUEEN'), ('NAIROBI', 'KENYA', 'SUVA', 'FIJI'), ('DENMARK', 'KRONE', 'RUSSIA', 'RUBLE'), ('TBILISI', 'GEORGIA', 'THIMPHU', 'BHUTAN'), ('RARE', 'RARELY', 'OCCASIONAL', 'OCCASIONALLY'), ('ARGENTINA', 'ARGENTINEAN', 'SPAIN', 'SPANISH'), ('IRELAND', 'IRISH', 'MALTA', 'MALTESE'), ('TIRANA', 'ALBANIA', 'ASTANA', 'KAZAKHSTAN'), ('ASTANA', 'KAZAKHSTAN', 'COPENHAGEN', 'DENMARK'), ('DREAM', 'DREAMS', 'GOAT', 'GOATS'), ('HUSBAND', 'WIFE', 'KING', 'QUEEN'), ('ASHGABAT', 'TURKMENISTAN', 'BERN', 'SWITZERLAND'), ('RABAT', 'MOROCCO', 'VADUZ', 'LIECHTENSTEIN'), ('RENO', 'NEVADA', 'WORCESTER', 'MASSACHUSETTS'), ('LOGICAL', 'ILLOGICAL', 'CONVINCING', 'UNCONVINCING'), ('FEEDING', 'FED', 'SLEEPING', 'SLEPT'), ('STEPSON', 'STEPDAUGHTER', 'FATHER', 'MOTHER'), ('DOLLAR', 'DOLLARS', 'PEAR', 'PEARS'), ('VIENTIANE', 'LAOS', 'BRATISLAVA', 'SLOVAKIA'), ('BOSTON', 'MASSACHUSETTS', 'DENVER', 'COLORADO'), ('FEEDING', 'FED', 'INCREASING', 'INCREASED'), ('QUITO', 'ECUADOR', 'SUVA', 'FIJI'), ('SNAKE', 'SNAKES', 'PEAR', 'PEARS'), ('LUSAKA', 'ZAMBIA', 'SUVA', 'FIJI'), ('BANANA', 'BANANAS', 'COW', 'COWS'), ('BELGRADE', 'SERBIA', 'BUJUMBURA', 'BURUNDI'), ('CODE', 'CODING', 'DISCOVER', 'DISCOVERING'), ('RUSSIA', 'RUSSIAN', 'ALBANIA', 'ALBANIAN'), ('PLAYING', 'PLAYED', 'LOOKING', 'LOOKED'), ('BEIRUT', 'LEBANON', 'CANBERRA', 'AUSTRALIA'), ('FINGER', 'FINGERS', 'COW', 'COWS'), ('PLEASANT', 'UNPLEASANT', 'TASTEFUL', 'DISTASTEFUL'), ('SLOW', 'SLOWS', 'INCREASE', 'INCREASES'), ('ASTANA', 'KAZAKHSTAN', 'BRATISLAVA', 'SLOVAKIA'), ('OXNARD', 'CALIFORNIA', 'PHOENIX', 'ARIZONA'), ('VALLETTA', 'MALTA', 'BERN', 'SWITZERLAND'), ('GROOM', 'BRIDE', 'GRANDSON', 'GRANDDAUGHTER'), ('DECREASE', 'DECRE ...
# incorrect -> correct
# {('IMPLEMENT', 'IMPLEMENTING', 'SCREAM', 'SCREAMING'), ('OMAHA', 'NEBRASKA', 'IRVINE', 'CALIFORNIA'), ('MAN', 'WOMAN', 'BROTHER', 'SISTER'), ('RESPONSIBLE', 'IRRESPONSIBLE', 'COMFORTABLE', 'UNCOMFORTABLE'), ('EFFICIENT', 'EFFICIENTLY', 'HAPPY', 'HAPPILY'), ('GENERATE', 'GENERATES', 'SIT', 'SITS'), ('DESCRIBE', 'DESCRIBES', 'WRITE', 'WRITES'), ('CAR', 'CARS', 'LION', 'LIONS'), ('PORTLAND', 'OREGON', 'WICHITA', 'KANSAS'), ('CONVINCING', 'UNCONVINCING', 'LOGICAL', 'ILLOGICAL'), ('TAKING', 'TOOK', 'SAYING', 'SAID'), ('SLOW', 'SLOWEST', 'BIG', 'BIGGEST'), ('WIDE', 'WIDEST', 'WEAK', 'WEAKEST'), ('HIGH', 'HIGHEST', 'COOL', 'COOLEST'), ('OTTAWA', 'CANADA', 'TBILISI', 'GEORGIA'), ('GENERATING', 'GENERATED', 'TAKING', 'TOOK'), ('WICHITA', 'KANSAS', 'RENO', 'NEVADA'), ('CAT', 'CATS', 'ONION', 'ONIONS'), ('COMPUTER', 'COMPUTERS', 'LION', 'LIONS'), ('ENHANCING', 'ENHANCED', 'SITTING', 'SAT'), ('WRITE', 'WRITING', 'MOVE', 'MOVING'), ('THINK', 'THINKS', 'ENHANCE', 'ENHANCES'), ('SCREAMING', 'SCREAMED', 'SAYING', 'SAID'), ('INCREASE', 'INCREASING', 'SLOW', 'SLOWING'), ('VADUZ', 'LIECHTENSTEIN', 'BRUSSELS', 'BELGIUM'), ('SHORT', 'SHORTER', 'COLD', 'COLDER'), ('AUSTIN', 'TEXAS', 'CINCINNATI', 'OHIO'), ('PLAY', 'PLAYING', 'SLOW', 'SLOWING'), ('WARM', 'WARMER', 'OLD', 'OLDER'), ('FONTANA', 'CALIFORNIA', 'DETROIT', 'MICHIGAN'), ('GO', 'GOING', 'ENHANCE', 'ENHANCING'), ('EASY', 'EASIER', 'LOW', 'LOWER'), ('COLOR', 'COLORS', 'ROAD', 'ROADS'), ('TOLEDO', 'OHIO', 'LUBBOCK', 'TEXAS'), ('MUSCAT', 'OMAN', 'SANTIAGO', 'CHILE'), ('SPEAK', 'SPEAKS', 'SEARCH', 'SEARCHES'), ('GENERATING', 'GENERATED', 'STRIKING', 'STRUCK'), ('HONOLULU', 'HAWAII', 'MODESTO', 'CALIFORNIA'), ('HONOLULU', 'HAWAII', 'GLENDALE', 'ARIZONA'), ('GRANDSON', 'GRANDDAUGHTER', 'BROTHER', 'SISTER'), ('HIALEAH', 'FLORIDA', 'SACRAMENTO', 'CALIFORNIA'), ('JACKSONVILLE', 'FLORIDA', 'LAREDO', 'TEXAS'), ('FAST', 'FASTER', 'LOW', 'LOWER'), ('BAGHDAD', 'IRAQ', 'BELGRADE', 'SERBIA'), ('SHUFFLE', 'SHUFFLING', 'ENHANCE', 'ENHANCING'), ('GENERATE', 'GENERATES', 'THINK', 'THINKS'), ('KNOWN', 'UNKNOWN', 'LIKELY', 'UNLIKELY'), ('SHARP', 'SHARPER', 'OLD', 'OLDER'), ('INFREQUENT', 'INFREQUENTLY', 'SLOW', 'SLOWLY'), ('SWIM', 'SWIMMING', 'SCREAM', 'SCREAMING'), ('LIKELY', 'UNLIKELY', 'ACCEPTABLE', 'UNACCEPTABLE'), ('BULGARIA', 'BULGARIAN', 'SLOVAKIA', 'SLOVAKIAN'), ('SEEING', 'SAW', 'JUMPING', 'JUMPED'), ('PREDICT', 'PREDICTS', 'ENHANCE', 'ENHANCES'), ('IMPLEMENTING', 'IMPLEMENTED', 'FALLING', 'FELL'), ('TAMPA', 'FLORIDA', 'LAREDO', 'TEXAS'), ('ARLINGTON', 'TEXAS', 'GLENDALE', 'ARIZONA'), ('READING', 'READ', 'SITTING', 'SAT'), ('WRITING', 'WROTE', 'MOVING', 'MOVED'), ('WALK', 'WALKING', 'MOVE', 'MOVING'), ('SWIFT', 'SWIFTLY', 'INFREQUENT', 'INFREQUENTLY'), ('PARAMARIBO', 'SURINAME', 'TBILISI', 'GEORGIA'), ('TRIPOLI', 'LIBYA', 'BELGRADE', 'SERBIA'), ('POLICEMAN', 'POLICEWOMAN', 'GRANDFATHER', 'GRANDMOTHER'), ('COLOR', 'COLORS', 'ONION', 'ONIONS'), ('PARAMARIBO', 'SURINAME', 'ANTANANARIVO', 'MADAGASCAR'), ('CHILD', 'CHILDREN', 'LION', 'LIONS'), ('ONION', 'ONIONS', 'LION', 'LIONS'), ('LOOKING', 'LOOKED', 'FEEDING', 'FED'), ('CODE', 'CODING', 'SEE', 'SEEING'), ('WRITE', 'WRITING', 'SCREAM', 'SCREAMING'), ('INDIANAPOLIS', 'INDIANA', 'WICHITA', 'KANSAS'), ('STRANGE', 'STRANGEST', 'BAD', 'WORST'), ('SLOW', 'SLOWLY', 'HAPPY', 'HAPPILY'), ('SHORT', 'SHORTEST', 'SMART', 'SMARTEST'), ('NASHVILLE', 'TENNESSEE', 'WICHITA', 'KANSAS'), ('KNOWING', 'KNEW', 'FEEDING', 'FED'), ('VILNIUS', 'LITHUANIA', 'BRUSSELS', 'BELGIUM'), ('MOVING', 'MOVED', 'GENERATING', 'GENERATED'), ('HUNTSVILLE', 'ALABAMA', 'WICHITA', 'KANSAS'), ('LONDON', 'ENGLAND', 'SANTIAGO', 'CHILE'), ('WIDE', 'WIDER', 'OLD', 'OLDER'), ('SAFE', 'SAFER', 'NEW', 'NEWER'), ('LOUD', 'LOUDER', 'COOL', 'COOLER'), ('HAND', 'HANDS', 'GOAT', 'GOATS'), ('HUSBAND', 'WIFE', 'FATHER', 'MOTHER'), ('GARLAND', 'TEXAS', 'RENO', 'NEVADA'), ('RENO', 'NEVADA', 'AMARILLO', 'TEXAS'), ('SAY', 'SAYING', 'ENHANCE', 'ENHANCING'), ('JUMP', 'JUMPING', 'FLY', 'FLYING'), ('SCREAM', 'SCREAMS', ' ...
#
#
# Word2Vec -> Unbiased_Word2Vec
# msr
# Accuracy: 0.7362857142857143 -> 0.7365714285714285
# correct -> incorrect
# {('CHANGED', 'CHANGES', 'RAISED', 'RAISES'), ('TIGHTER', 'TIGHTEST', 'GENTLER', 'GENTLEST'), ('MOVES', 'MOVED', 'STUDIES', 'STUDIED'), ('CLASSIER', 'CLASSY', 'WORSE', 'BAD'), ('COSTLIEST', 'COSTLY', 'TALLEST', 'TALL'), ('FAIRER', 'FAIREST', 'MILDER', 'MILDEST'), ('BROAD', 'BROADEST', 'TALL', 'TALLEST'), ('LIVES', 'LIVE', 'WORKS', 'WORK'), ('TIMES', 'TIME', 'TERMS', 'TERM'), ('HEAVIEST', 'HEAVY', 'POOREST', 'POOR'), ('NUMBER', 'NUMBERS', 'RESIDENT', 'RESIDENTS')}
# incorrect -> correct
# {('STEADIER', 'STEADY', 'WIDER', 'WIDE'), ('BUILT', 'BUILD', 'FOLLOWED', 'FOLLOW'), ('PATIENTS', 'PATIENT', 'WOMEN', 'WOMAN'), ('PATIENT', 'PATIENTS', 'WOMAN', 'WOMEN'), ('CONDITIONS', 'CONDITION', 'MEN', 'MAN'), ('CONDITION', 'CONDITIONS', 'MAN', 'MEN'), ('INCREASED', 'INCREASE', 'CAME', 'COME'), ('STEADIEST', 'STEADY', 'WIDEST', 'WIDE'), ('CITIES', 'CITY', 'MEN', 'MAN'), ('BECOMES', 'BECAME', 'REACHES', 'REACHED'), ('FEWER', 'FEWEST', 'CLEANER', 'CLEANEST'), ('TIGHTEST', 'TIGHTER', 'CLASSIEST', 'CLASSIER'), ('INVESTORS', 'INVESTOR', 'MEN', 'MAN')}
#
# google_analogies
# Accuracy: 0.7401448525607863 -> 0.7373512674599069
# correct -> incorrect
# {('BROTHER', 'SISTER', 'HUSBAND', 'WIFE'), ('HUSBAND', 'WIFE', 'STEPFATHER', 'STEPMOTHER'), ('EAGLE', 'EAGLES', 'CAR', 'CARS'), ('SONS', 'DAUGHTERS', 'HUSBAND', 'WIFE'), ('UNCLE', 'AUNT', 'STEPSON', 'STEPDAUGHTER'), ('POLICEMAN', 'POLICEWOMAN', 'DAD', 'MOM'), ('BROTHERS', 'SISTERS', 'STEPSON', 'STEPDAUGHTER'), ('HE', 'SHE', 'POLICEMAN', 'POLICEWOMAN'), ('HUSBAND', 'WIFE', 'GRANDSON', 'GRANDDAUGHTER'), ('STEPBROTHER', 'STEPSISTER', 'PRINCE', 'PRINCESS'), ('DECIDED', 'UNDECIDED', 'IMPRESSIVE', 'UNIMPRESSIVE'), ('SLOW', 'SLOWING', 'RUN', 'RUNNING'), ('SAY', 'SAYING', 'RUN', 'RUNNING'), ('MINNEAPOLIS', 'MINNESOTA', 'HONOLULU', 'HAWAII'), ('LION', 'LIONS', 'BANANA', 'BANANAS'), ('POLICEMAN', 'POLICEWOMAN', 'HE', 'SHE'), ('POLICEMAN', 'POLICEWOMAN', 'FATHER', 'MOTHER'), ('FATHER', 'MOTHER', 'HUSBAND', 'WIFE'), ('POLICEMAN', 'POLICEWOMAN', 'UNCLE', 'AUNT'), ('POLICEMAN', 'POLICEWOMAN', 'STEPSON', 'STEPDAUGHTER'), ('READ', 'READING', 'DESCRIBE', 'DESCRIBING'), ('POLICEMAN', 'POLICEWOMAN', 'NEPHEW', 'NIECE'), ('SON', 'DAUGHTER', 'HUSBAND', 'WIFE'), ('FATHER', 'MOTHER', 'STEPSON', 'STEPDAUGHTER'), ('MIAMI', 'FLORIDA', 'GARLAND', 'TEXAS'), ('STEPFATHER', 'STEPMOTHER', 'NEPHEW', 'NIECE'), ('KING', 'QUEEN', 'HUSBAND', 'WIFE'), ('POLICEMAN', 'POLICEWOMAN', 'GROOM', 'BRIDE'), ('POLICEMAN', 'POLICEWOMAN', 'PRINCE', 'PRINCESS'), ('BOY', 'GIRL', 'STEPSON', 'STEPDAUGHTER'), ('SHORT', 'SHORTEST', 'GREAT', 'GREATEST'), ('POLICEMAN', 'POLICEWOMAN', 'GRANDFATHER', 'GRANDMOTHER'), ('HUSBAND', 'WIFE', 'UNCLE', 'AUNT'), ('SEARCH', 'SEARCHES', 'SCREAM', 'SCREAMS'), ('POLICEMAN', 'POLICEWOMAN', 'SONS', 'DAUGHTERS'), ('HUSBAND', 'WIFE', 'GRANDPA', 'GRANDMA'), ('PRINCE', 'PRINCESS', 'POLICEMAN', 'POLICEWOMAN'), ('THINK', 'THINKING', 'GO', 'GOING'), ('HUSBAND', 'WIFE', 'KING', 'QUEEN'), ('SWIM', 'SWIMMING', 'RUN', 'RUNNING'), ('TASTEFUL', 'DISTASTEFUL', 'IMPRESSIVE', 'UNIMPRESSIVE'), ('BROTHERS', 'SISTERS', 'HUSBAND', 'WIFE'), ('GRANDFATHER', 'GRANDMOTHER', 'STEPSON', 'STEPDAUGHTER'), ('HUSBAND', 'WIFE', 'PRINCE', 'PRINCESS'), ('HIS', 'HER', 'POLICEMAN', 'POLICEWOMAN'), ('HUSBAND', 'WIFE', 'BROTHERS', 'SISTERS'), ('MUSCAT', 'OMAN', 'QUITO', 'ECUADOR'), ('NEPHEW', 'NIECE', 'HUSBAND', 'WIFE'), ('KIEV', 'UKRAINE', 'LJUBLJANA', 'SLOVENIA'), ('KING', 'QUEEN', 'STEPSON', 'STEPDAUGHTER'), ('SHORT', 'SHORTEST', 'TALL', 'TALLEST'), ('HUSBAND', 'WIFE', 'NEPHEW', 'NIECE'), ('SANTIAGO', 'CHILE', 'APIA', 'SAMOA'), ('TACOMA', 'WASHINGTON', 'PORTLAND', 'OREGON'), ('POLICEMAN', 'POLICEWOMAN', 'HIS', 'HER'), ('SONS', 'DAUGHTERS', 'STEPSON', 'STEPDAUGHTER'), ('GRANDPA', 'GRANDMA', 'STEPSON', 'STEPDAUGHTER'), ('POLICEMAN', 'POLICEWOMAN', 'BROTHER', 'SISTER'), ('STEPBROTHER', 'STEPSISTER', 'FATHER', 'MOTHER'), ('KING', 'QUEEN', 'POLICEMAN', 'POLICEWOMAN'), ('POLICEMAN', 'POLICEWOMAN', 'KING', 'QUEEN'), ('WIDE', 'WIDER', 'NEW', 'NEWER'), ('HUSBAND', 'WIFE', 'GROOM', 'BRIDE'), ('POLICEMAN', 'POLICEWOMAN', 'BROTHERS', 'SISTERS'), ('HUSBAND', 'WIFE', 'SON', 'DAUGHTER'), ('TEHRAN', 'IRAN', 'ACCRA', 'GHANA'), ('SLOVAKIA', 'SLOVAKIAN', 'ARGENTINA', 'ARGENTINEAN'), ('HUSBAND', 'WIFE', 'MAN', 'WOMAN'), ('SURE', 'UNSURE', 'REASONABLE', 'UNREASONABLE'), ('STEPBROTHER', 'STEPSISTER', 'BROTHER', 'SISTER'), ('VANISHING', 'VANISHED', 'SAYING', 'SAID'), ('GRANDPA', 'GRANDMA', 'HUSBAND', 'WIFE'), ('DAD', 'MOM', 'STEPSON', 'STEPDAUGHTER'), ('TOLEDO', 'OHIO', 'LAREDO', 'TEXAS'), ('NASSAU', 'BAHAMAS', 'ROME', 'ITALY'), ('POLICEMAN', 'POLICEWOMAN', 'GRANDPA', 'GRANDMA'), ('POLICEMAN', 'POLICEWOMAN', 'GRANDSON', 'GRANDDAUGHTER'), ('SURE', 'UNSURE', 'CONVENIENT', 'INCONVENIENT'), ('STEPBROTHER', 'STEPSISTER', 'POLICEMAN', 'POLICEWOMAN'), ('MONTEVIDEO', 'URUGUAY', 'NOUAKCHOTT', 'MAURITANIA'), ('OMAHA', 'NEBRASKA', 'LAREDO', 'TEXAS'), ('POLICEMAN', 'POLICEWOMAN', 'SON', 'DAUGHTER'), ('NEPHEW', 'NIECE', 'STEPSON', 'STEPDAUGHTER'), ('BROTHER', 'SISTER', 'STEPSON', 'STEPDAUGHTER'), ('DEBUG', 'DEBUGGING', 'RUN', 'RUNNING'), ('CERTAIN', 'UNCERTAIN', 'ACCEPTABLE', 'UNACCEPTABLE'), ('HUSBAND', 'WIFE', 'SONS' ...
# incorrect -> correct
# {('MONKEY', 'MONKEYS', 'WOMAN', 'WOMEN'), ('CAT', 'CATS', 'MAN', 'MEN'), ('ZAGREB', 'CROATIA', 'BAMAKO', 'MALI'), ('ROAD', 'ROADS', 'COLOR', 'COLORS'), ('DOG', 'DOGS', 'MAN', 'MEN'), ('STEPSON', 'STEPDAUGHTER', 'UNCLE', 'AUNT'), ('BUJUMBURA', 'BURUNDI', 'DOHA', 'QATAR'), ('PRINCE', 'PRINCESS', 'DAD', 'MOM'), ('HUSBAND', 'WIFE', 'POLICEMAN', 'POLICEWOMAN'), ('BALTIMORE', 'MARYLAND', 'HIALEAH', 'FLORIDA'), ('MINNEAPOLIS', 'MINNESOTA', 'FONTANA', 'CALIFORNIA'), ('BISHKEK', 'KYRGYZSTAN', 'KABUL', 'AFGHANISTAN'), ('TULSA', 'OKLAHOMA', 'GLENDALE', 'ARIZONA'), ('FIND', 'FINDS', 'VANISH', 'VANISHES'), ('IMPRESSIVE', 'UNIMPRESSIVE', 'REASONABLE', 'UNREASONABLE'), ('HORSE', 'HORSES', 'WOMAN', 'WOMEN'), ('INDIANAPOLIS', 'INDIANA', 'ANAHEIM', 'CALIFORNIA'), ('CAT', 'CATS', 'WOMAN', 'WOMEN'), ('RUNNING', 'RAN', 'WRITING', 'WROTE'), ('PITTSBURGH', 'PENNSYLVANIA', 'PHOENIX', 'ARIZONA'), ('DOG', 'DOGS', 'WOMAN', 'WOMEN'), ('AMMAN', 'JORDAN', 'BRATISLAVA', 'SLOVAKIA'), ('OMAHA', 'NEBRASKA', 'HIALEAH', 'FLORIDA'), ('GROOM', 'BRIDE', 'UNCLE', 'AUNT'), ('DONKEY', 'DONKEYS', 'MAN', 'MEN'), ('SIMPLE', 'SIMPLER', 'NEW', 'NEWER'), ('ASTANA', 'KAZAKHSTAN', 'BUJUMBURA', 'BURUNDI'), ('MADISON', 'WISCONSIN', 'DALLAS', 'TEXAS'), ('ENGLAND', 'ENGLISH', 'CHILE', 'CHILEAN'), ('MONKEY', 'MONKEYS', 'MAN', 'MEN'), ('CAR', 'CARS', 'WOMAN', 'WOMEN'), ('WIDE', 'WIDER', 'LOW', 'LOWER'), ('GROOM', 'BRIDE', 'BROTHERS', 'SISTERS'), ('GLENDALE', 'ARIZONA', 'OXNARD', 'CALIFORNIA'), ('GARLAND', 'TEXAS', 'GLENDALE', 'ARIZONA'), ('GLENDALE', 'ARIZONA', 'MEMPHIS', 'TENNESSEE'), ('HORSE', 'HORSES', 'MAN', 'MEN'), ('IRAN', 'RIAL', 'ARGENTINA', 'PESO'), ('SEEING', 'SAW', 'VANISHING', 'VANISHED'), ('AMMAN', 'JORDAN', 'BUJUMBURA', 'BURUNDI'), ('RAPID', 'RAPIDLY', 'SAFE', 'SAFELY')}

# %% [markdown]
# ## Experiment with your own analogies
#
# Change the variables `a`, `b`, `c` to see the results of each embedding:

# %%
a = 'male'
# is to
b = 'female'
# as
c = 'doctor'
# is to ...

print(f"{a} is to {b} as {c} is to...")
for model_name, model in MODELS.items():
    print(model_name + ': ', end='')
    v = model.get_vector(b) - model.get_vector(a) + model.get_vector(c)
    d = model.most_similar(v, topn=3)
    print(d)
# Out:
# male is to female as doctor is to...
# GloVe_Stanford: [('doctor', 0.9061827063560486), ('physician', 0.6464920043945312), ('nurse', 0.5715017914772034)]
# Unbiased_GloVe: [('doctor', 0.8750905394554138), ('doctors', 0.5951226949691772), ('physician', 0.5413261651992798)]
# Word2Vec: [('doctor', 0.8938288688659668), ('physician', 0.6915890574455261), ('doctors', 0.6790844202041626)]
# Unbiased_Word2Vec: [('doctor', 0.8294335007667542), ('gynecologist', 0.6915062069892883), ('physician', 0.6491522789001465)]

# %% [markdown]
# # References
#
# [1] Pennington, J., Socher, R., & Manning, C. D. (2014, October). Glove: Global vectors for word representation. In Proceedings of the 2014 conference on empirical methods in natural language processing (EMNLP) (pp. 1532-1543).
#
# [2] Zhao, J., Zhou, Y., Li, Z., Wang, W., & Chang, K. W. (2018). Learning gender-neutral word embeddings. arXiv preprint arXiv:1809.01496.
#
# [3] Mikolov, T., Chen, K., Corrado, G., & Dean, J. (2013). Efficient estimation of word representations in vector space. arXiv preprint arXiv:1301.3781.
#
# [4] Bolukbasi, T., Chang, K. W., Zou, J. Y., Saligrama, V., & Kalai, A. T. (2016). Man is to computer programmer as woman is to homemaker? debiasing word embeddings. Advances in neural information processing systems, 29.
